# %%
import pandas as pd
df = pd.read_csv('data_agg_final.csv')

# %%
df
# Out:
#      Unnamed: 0 Открыт_дата  День недели  Месяц   Год  Неделя  ЗП  Время года  \
# 0             0  2022-09-01            3      9  2022       1   0           3
# 1             1  2022-09-02            4      9  2022       1   0           3
# 2             2  2022-09-03            5      9  2022       1   0           3
# 3             3  2022-09-04            6      9  2022       1   0           3
# 4             4  2022-09-05            0      9  2022       1   0           3
# ..          ...         ...          ...    ...   ...     ...  ..         ...
# 415         415  2023-10-22            6     10  2023       4   0           3
# 416         416  2023-10-23            0     10  2023       4   0           3
# 417         417  2023-10-24            1     10  2023       4   0           3
# 418         418  2023-10-25            2     10  2023       4   0           3
# 419         419  2023-10-26            3     10  2023       4   0           3
#
# ...

# %%
df = df[['Открыт_дата', 'Сумма по чеку, руб.']]

# %%
df['Открыт_дата'] = pd.to_datetime(df['Открыт_дата'], dayfirst=True)

# %%
import matplotlib.pyplot as plt

# %%
f = plt.figure() 
f.set_figwidth(25) 
f.set_figheight(10) 
plt.plot(df['Открыт_дата'], df['Сумма по чеку, руб.'])
plt.show()

# %%
df[df['Сумма по чеку, руб.']>150000]
# Out:
#     Открыт_дата  Сумма по чеку, руб.
# 260  2023-05-20             153018.0
# 280  2023-06-09             198873.0
# 414  2023-10-21             150704.6

# %%
df[df['Открыт_дата']=='2023-06-7']
# Out:
#     Открыт_дата  Сумма по чеку, руб.
# 278  2023-06-07              95821.0

# %%
df[df['Сумма по чеку, руб.']<50000]
# Out:
#     Открыт_дата  Сумма по чеку, руб.
# 121  2022-12-31              42497.5
# 123  2023-01-03              42310.0
# 129  2023-01-09              47685.0
# 301  2023-06-30              46430.0

# %%
df['Сумма по чеку, руб.'].quantile(0.10)
# Out:
# 67354.5

# %%
df['Сумма по чеку, руб.'].quantile(0.90)
# Out:
# 112330.35
