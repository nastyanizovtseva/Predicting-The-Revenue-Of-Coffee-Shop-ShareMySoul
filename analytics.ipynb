# %% [markdown]
# ### Импорт библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Импорт данных

# %%
sdf = pd.read_csv('Обработанные данные.csv', sep=';', index_col=0)
sdf.head(2)
# Out:
#   Открыт_дата  День недели  Месяц   Год  Неделя  ЗП  Время года  \
# 0  2022-09-01            3      9  2022       1   0           3
# 1  2022-09-02            4      9  2022       1   0           3
#
#    Сумма по чеку, руб.
# 0              96630.0
# 1             108024.5

# %% [markdown]
# ### Преобразование

# %%
df['Открыт_дата'] = pd.to_datetime(df['Открыт_дата'])

# %% [markdown]
# ### Аналитика

# %% [markdown]
# График общего **количества чеков** по дням, неделям, месяцам и годам за все время

# %%
# Создание временных рядов
sdf['День'] = sdf['Открыт'].dt.date
sdf['Неделя'] = sdf['Открыт'].dt.to_period('W')
sdf['Месяц'] = sdf['Открыт'].dt.to_period('M')
sdf['Год'] = sdf['Открыт'].dt.year

# %%
# Группировка
daily_count = df.groupby('День недели').size()
weekly_count = df.groupby('Неделя').size()
monthly_count = df.groupby('Месяц').size()
yearly_count = df.groupby('Год').size()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

daily_count.plot(ax=axes[0, 0], title='Колиечество чеков по дням', marker='o', color='brown')
weekly_count.plot(ax=axes[0, 1], title='Колиечество чеков по неделям', marker='o', color='brown')
monthly_count.plot(ax=axes[1, 0], title='Колиечество чеков по месяцам', marker='o', color='brown')
yearly_count.plot(ax=axes[1, 1], title='Колиечество чеков по годам', marker='o', color='brown')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

weekly_count.plot(ax=axes[0], kind='bar', title='Количество чеков по неделям', color='brown')
monthly_count.plot(ax=axes[1], kind='bar', title='Количество чеков по месяцам', color='brown')

plt.tight_layout()
plt.show()

# %% [markdown]
# Количество чеков по месяцам

# %%
monthly_total_count = sdf.groupby('Месяц').size()

for month, count in monthly_total_count.items():
    print(f"{month.strftime('%B')} - {count}")
# Out:
# January - 752
# February - 758
# March - 742
# April - 780
# May - 730
# June - 722
# July - 714
# August - 728
# September - 4324
# October - 4505
# November - 3887
# December - 3479
# January - 4012
# February - 3657
# March - 4442
# April - 4507
# May - 4886
# June - 3817
# July - 3553
# August - 3665
# September - 4027
# October - 3234
# November - 1429
# December - 1490

# %% [markdown]
# ### Сохранение датафрейма

# %%
sdf.to_csv('to-analytics.csv', index=False)

# %%
print(sum(list(map(int, input().split()))))
# Out:
# 5 5
# 10

# %% [markdown]
# # мусорка

# %%
df = pd.read_csv('data_agg.csv', delimiter=',', index_col=0)
df.head(2)
# Out:
#   Открыт_дата  День недели  Месяц   Год  Неделя  ЗП  Время года  \
# 0  2022-09-01            3      9  2022       1   0           3
# 1  2022-09-02            4      9  2022       1   0           3
#
#    Сумма по чеку, руб.
# 0              96630.0
# 1             108024.5

# %%
print(df.dtypes)
# Out:
# Открыт_дата            datetime64[ns]
# День недели                     int64
# Месяц                           int64
# Год                             int64
# Неделя                          int64
# ЗП                              int64
# Время года                      int64
# Сумма по чеку, руб.           float64
# dtype: object

# %%
df['Открыт_дата'] = pd.to_datetime(df['Открыт_дата'])

# %%
# Создание временных рядов
#df['День'] = df['Открыт_дата'].dt.date
#df['Неделя'] = df['Открыт_дата'].dt.to_period('W')
#df['Месяц'] = df['Открыт_дата'].dt.to_period('M')
#df['Год'] = df['Открыт_дата'].dt.year

# %%
# Группировка
daily_count = df.groupby('День недели').size()
weekly_count = df.groupby('Неделя').size()
monthly_count = df.groupby('Месяц').size()
yearly_count = df.groupby('Год').size()
